# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\k2003\onedrive\문서\github\kcqt_csi_project\venv\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\k2003\onedrive\문서\github\kcqt_csi_project\venv\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\k2003\onedrive\문서\github\kcqt_csi_project\venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\k2003\onedrive\문서\github\kcqt_csi_project\venv\lib\site-packages (from requests) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\k2003\onedrive\문서\github\kcqt_csi_project\venv\lib\site-packages (from requests) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting beautifulsoup4 (from bs4)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->bs4)
#   Downloading soupsieve-2.8.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\k2003\onedrive\문서\github\kcqt_csi_project\venv\lib\site-packages (from beautifulsoup4->bs4) (4.15.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading soupsieve-2.8.1-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4
#
#    ---------------------------------------- 0/3 [soupsieve]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    -------------------------- ------------- 2/3 [bs4]
#    ---------------------------------------- 3/3 [bs4]
#
# Successfully installed beautifulsoup4-4.14.3 bs4-0.0.2 soupsieve-2.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
response=requests.get("https://startcoding.pythonanywhere.com/basic")
response.status_code
# Out:
# 200

# %%
response.text

# %%
import requests
from bs4 import BeautifulSoup

response=requests.get("https://startcoding.pythonanywhere.com/basic")
html=response.text
soup=BeautifulSoup(html,'html.parser')
soup.select_one(".brand-name").text
# Out:
# '스타트코딩'
