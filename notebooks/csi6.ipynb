# %%
pip install pandas

# %%
pip install openpyxl

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

data=[]
for i in range(1,5):
    response=requests.get(f"https://startcoding.pythonanywhere.com/basic?page={i}")
    html=response.text
    soup=BeautifulSoup(html,'html.parser')
    items = soup.select(".product")
    for item in items:
        category=item.select_one(".product-category").text
        name=item.select_one(".product-name").text
        link=item.select_one(".product-name > a").attrs['href']
        price=item.select_one(".product-price").text.split('원')[0].replace(',','')
        print(category,name,link,price)
        data.append([category,name,link,price])

# %%
response=requests.get("https://gcloud.csi.go.kr/cmq/qtr/qltRqst/rqstRcvList.do")
html=response.text
soup=BeautifulSoup(html,'html.parser')
soup.select_one(".odd.gradeX")
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]> <html lang="en" class="ie8 no-js"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9 no-js"> <![endif]-->
# <!--[if !IE]><!-->
# <html lang="ko">
# <!--<![endif]-->
# <!-- head 시작 -->
# <head>
# <meta charset="utf-8"/>
# <title></title>
# <link href="https://www.csi.go.kr/" rel="canonical"/>
# <meta content="건설공사 안전관리 종합정보망은 건설공사 안전관리에 필요한 정보를 통합(연계) 관리하고 공동활용을 촉진함으로써 건설현장의 안전을 확보합니다." name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="건설공사 안전관리 종합정보망" property="og:title"/>
# <meta content="건설공사 안전관리 종합정보망은 건설공사 안전관리에 필요한 정보를 통합(연계) 관리하고 공동활용을 촉진함으로써 건설현장의 안전을 확보합니다." property="og:description"/>
# <meta content="https://www.csi.go.kr/com/img/common/header/logo.png" property="og:image"/>
# <meta content="https://www.csi.go.kr/" property="og:url"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="건설공사 안전관리 종합정보망" name="twitter:title"/>
# <meta content="건설공사 안전관리 종합정보망은 건설공사 안전관리에 필요한 정보를 통합(연계) 관리하고 공동활용을 촉진함으로써 건설현장의 안전을 확보합니다." name="twitter:description"/>
# <meta content="https://www.csi.go.kr/com/img/common/header/logo.png" name="twitter:image"/>
# <meta content="https://www.csi.go.kr/" name="twitter:domain"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
# <script type="text/javascript">
#         var _contextPath = "/cmq"; //contextPath 설정
#         var vworldApiKey = "";
#     </script>
# <link href="/cmq/com/favicon.ico" rel="shortcut icon">
# <!-- 공통 -->
# <link href="/cmq/com/plugins/font-awesome/css/font-awesome.css" rel="stylesheet" type="text/css"/>
# <link href="/cmq/com/plugins/simple-line-icons/simple-line-icons.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/plugins/jquery.min.js" type="text/javascript"></script>
# <script src="/cmq/com/plugins/js.cookie.min.js" type="text/javascript"></script>
# <script src="/cmq/com/js/axios.min.js" type="text/javascript"></script>
# <script src="/cmq/com/js/app.js" type="text/javascript"></script>
# <script src="/cmq/com/js/auth/AuthTypeCd.js" type="text/javascript"></script>
# <!-- bootstrap -->
# <link href="/cmq/com/plugins/bootstrap/css/bootstrap.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/plugins/bootstrap/js/bootstrap.min.js" type="text/javascript"></script>
# <!-- bootstrap-datepicker -->
# <link href="/cmq/com/plugins/bootstrap-datepicker/css/bootstrap-datepicker3.css" rel="stylesheet" type="text/css"/>
# <link href="/cmq/com/plugins/bootstrap-timepicker/css/bootstrap-timepicker.css" rel="stylesheet" type="text/css"/>
# <link href="/cmq/com/plugins/bootstrap-datetimepicker/css/bootstrap-datetimepicker.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/plugins/bootstrap-datepicker/js/bootstrap-datepicker.js" type="text/javascript"></script>
# <script src="/cmq/com/plugins/bootstrap-datepicker/locales/bootstrap-datepicker.kr.min.js" type="text/javascript"></script>
# <script src="/cmq/com/plugins/bootstrap-timepicker/js/bootstrap-timepicker.js" type="text/javascript"></script>
# <script src="/cmq/com/plugins/bootstrap-datetimepicker/js/bootstrap-datetimepicker.js" type="text/javascript"></script>
# <script src="/cmq/com/plugins/bootstrap-datetimepicker/js/locales/bootstrap-datetimepicker.kr.js" type="text/javascript"></script>
# <script src="/cmq/com/js/bootstrap-datepicker.kr.js" type="text/javascript"></script>
# <script src="/cmq/com/js/components-date-time-pickers.js?ver=1.0" type="text/javascript"></script>
# <!-- bootstrap-fileinput -->
# <link href="/cmq/com/plugins/bootstrap-fileinput/bootstrap-fileinput.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/plugins/bootstrap-fileinput/bootstrap-fileinput.js" type="text/javascript"></script>
# <!-- bootstrap-tabdrop -->
# <script src="/cmq/com/plugins/bootstrap-tabdrop/js/bootstrap-tabdrop.js" type="text/javascript"></script>
# <!-- jstree -->
# <!--
# 		<link href="/cmq/com/plugins/jstree/dist/themes/default/style.css" rel="stylesheet" type="text/css" />
# 		<script src="/cmq/com/plugins/jstree/dist/jstree.js" type="text/javascript"></script>
# 		<script src="/cmq/com/js/ui-tree.js" type="text/javascript"></script>
#  		-->
# <!-- datatables-managed -->
# <!--
# 		<script src="/cmq/com/js/datatable.js" type="text/javascript"></script>
# 		<script src="/cmq/com/plugins/datatables/datatables.min.js" type="text/javascript"></script>
# 		<script src="/cmq/com/plugins/datatables/plugins/bootstrap/datatables.bootstrap.js" type="text/javascript"></script>
# 		<script src="/cmq/com/js/table-datatables-managed.min.js" type="text/javascript"></script>
# 		-->
# <!-- bootstrap-touchspin -->
# <link href="/cmq/com/plugins/bootstrap-touchspin/bootstrap.touchspin.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/plugins/bootstrap-touchspin/bootstrap.touchspin.js" type="text/javascript"></script>
# <script src="/cmq/com/js/components-bootstrap-touchspin.js" type="text/javascript"></script>
# <!-- bootstrap-switch -->
# <link href="/cmq/com/plugins/bootstrap-switch/css/bootstrap-switch.min.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/plugins/bootstrap-switch/js/bootstrap-switch.min.js" type="text/javascript"></script>
# <script src="/cmq/com/js/components-bootstrap-switch.min.js" type="text/javascript"></script>
# <!-- bootstrap-toastr -->
# <link href="/cmq/com/plugins/bootstrap-toastr/toastr.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/plugins/bootstrap-toastr/toastr.js" type="text/javascript"></script>
# <script src="/cmq/com/js/ui-toastr.js" type="text/javascript"></script>
# <!-- jquery-ui -->
# <script src="/cmq/com/plugins/jquery-ui/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/cmq/com/js/ui-modals.js" type="text/javascript"></script>
# <!-- pace-loading -->
# <script src="/cmq/com/plugins/pace-1.0.2/pace.js" type="text/javascript"></script>
# <link href="/cmq/com/plugins/pace-1.0.2/themes/blue/pace-theme-loading-bar.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#         paceOptions = {
#             ajax: true, // enabled
#             document: true, // enabled
#             eventLag: false // disabled
#         };
#
#         $(function () {
#             $(document).ajaxStart(function () { Pace.restart(); });<!-- pace-loading -->
#         });
#     </script>
# <!-- splitter -->
# <link href="/cmq/com/plugins/jquery-touch-splitter/css/touchsplitter.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/plugins/jquery-touch-splitter/js/jquery.touchsplitter.js" type="text/javascript"></script>
# <!-- amcharts -->
# <script src="/cmq/com/plugins/amcharts/amcharts.js" type="text/javascript"></script>
# <script src="/cmq/com/plugins/amcharts/serial.js" type="text/javascript"></script>
# <script src="/cmq/com/plugins/amcharts/pie.js" type="text/javascript"></script>
# <script src="/cmq/com/plugins/amcharts/plugins/export/export.js" type="text/javascript"></script>
# <script src="/cmq/com/plugins/amcharts/themes/light.js" type="text/javascript"></script>
# <!-- quick-nav -->
# <!--
# 		<script src="/cmq/com/js/quick-sidebar.js" type="text/javascript"></script>
#         <script src="/cmq/com/js/quick-nav.js" type="text/javascript"></script>
#          -->
# <!-- jquery-slimscroll -->
# <script src="/cmq/com/plugins/jquery-slimscroll/jquery.slimscroll.min.js" type="text/javascript"></script>
# <!-- FlexSlider -->
# <link href="/cmq/com/plugins/flex-slider-2/css/flexslider.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/plugins/flex-slider-2/js/modernizr.js"></script>
# <script src="/cmq/com/plugins/flex-slider-2/js/jquery.flexslider.js"></script>
# <script src="/cmq/com/plugins/flex-slider-2/js/jquery.easing.js"></script>
# <script src="/cmq/com/plugins/flex-slider-2/js/jquery.mousewheel.js"></script>
# <script src="/cmq/com/plugins/flex-slider-2/js/demo.js"></script>
# <!-- layout & themes -->
# <link href="/cmq/com/skin/layout/css/components.css?var=1.0" id="style_components" rel="stylesheet" type="text/css"/>
# <link href="/cmq/com/skin/layout/css/plugins.css?var=1.0" rel="stylesheet" type="text/css"/>
# <link href="/cmq/com/skin/layout/css/layout.css?var=1.0" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/skin/layout/scripts/layout.js" type="text/javascript"></script>
# <!-- customizing -->
# <script src="/cmq/com/js/common.js" type="text/javascript"></script>
# <script src="/cmq/com/js/commonMsg.js" type="text/javascript"></script>
# <link href="/cmq/com/css/default.css?var=1.0" rel="stylesheet" type="text/css"/>
# <link href="/cmq/com/css/custom.css?var=1.0" rel="stylesheet" type="text/css"/>
# <link href="/cmq/com/css/login.css?var=1.0" rel="stylesheet" type="text/css"/>
# <!-- main renewal -->
# <link href="/cmq/com/css/main_renewal.css?var=1.1" rel="stylesheet" type="text/css"/>
# <link href="/cmq/com/css/page_search.css?var=1.0" rel="stylesheet" type="text/css"/>
# <!-- <link href="/cmq/com/css/page_quality.css?var=1.0" rel="stylesheet" type="text/css" /> -->
# <!-- custom -->
# <script src="/cmq/com/js/jquery.form.js" type="text/javascript"></script>
# <script src="/cmq/com/js/util_common.js?ver=1.8" type="text/javascript"></script>
# <script src="/cmq/com/js/util_datetime.js" type="text/javascript"></script>
# <script src="/cmq/com/js/util_popup.js?ver=1.9" type="text/javascript"></script>
# <script src="/cmq/com/js/util_string.js" type="text/javascript"></script>
# <script src="/cmq/com/js/jquery.table2excel.js" type="text/javascript"></script>
# <!--2024-04-04-->
# <script src="/cmq/com/js/lodash.min.js" type="text/javascript"></script>
# <script src="/cmq/com/js/util_axios.js" type="text/javascript"></script>
# <!-- innorix -->
# <link href="/cmq/com/innorix/innorix.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/innorix/innorix.js"></script>
# <!-- introjs -->
# <link href="/cmq/com/introjs/introjs.min.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/introjs/intro.min.js"></script>
# <!-- moment -->
# <script src="/cmq/com/js/moment/moment.min.js"></script>
# <script src="/cmq/com/js/moment/ko.js"></script>
# <!-- 파일 정보 -->
# <script src="/cmq/com/js/exif.js" type="text/javascript"></script>
# <!-- ========================= 리뉴얼 추가 & 수정 시작 ========================= -->
# <!-- 상단메뉴 - 20240801 추가 -->
# <link href="/cmq/com/plugins/top-menu/css/menu.css" rel="stylesheet" type="text/css"/>
# <script src="/cmq/com/plugins/top-menu/js/custom.js" type="text/javascript"></script>
# <!-- 슬라이드 bxslider - 20240801 추가 -->
# <script src="/cmq/com/plugins/jquery.bxslider/jquery.bxslider.js" type="text/javascript"></script>
# <script src="/cmq/com/plugins/jquery.bxslider/main.slides.js" type="text/javascript"></script>
# <link href="/cmq/com/plugins/jquery.bxslider/jquery.bxslider.css" rel="stylesheet" type="text/css"/>
# <!-- main renewal - 20240801 변경 -->
# <link href="/cmq/com/css/main_renewal_v2.0.css" rel="stylesheet" type="text/css">
# <!-- ========================= 리뉴얼 추가 & 수정 끝 ========================= -->
# <script src="/cmq/com/js/common/main.js?ver=2.6" type="text/javascript"></script>
# <script language="javascript">
#
#         //페이지정보
#         menuInfo.isSch = '';
#         menuInfo.systemCd = '';
#         menuInfo.systemNm = '';
#         menuInfo.menuId = '';
#         menuInfo.useYn = '';
#         menuInfo.upperMenuId = '';
#         menuInfo.upperUpperMenuId = '';
#         menuInfo.menuNm = '';
#         menuInfo.menuDesc = '';
#         menuInfo.menuTree = '';
#         menuInfo.menuRootId = '';
#         menuInfo.menuRoot = '';
#         menuInfo.activeMenuId = '';
#         menuInfo.targetPage = 'top-total-search';
#         menuInfo.targetSelfBlank = '_blank';
#         menuInfo.sysPageUriActive = '';
#
#         // console.log('initMenuInfo', menuInfo);
#
#         function moveUrl() {
#             // console.log($('#relationSite option:selected').val());
#             if ($('#relationSite option:selected').val() != '') {
#                 var win = window.open($('#relationSite option:selected').val(), '_blank');
#                 win.focus();
#             }
#         }
#
#         function noAccess() {
#             alert('접근 권한이 없습니다.');
#         }
#
#         // left 메뉴 출력(권한 적용)
#         function fnLeftMenuCreate(sysCd) {
#             $.ajax({
#                 url: "/cmq/com/selectLeftMenuAjax.do?sysCd=" + sysCd,
#                 contentType: "application/x-www-form-urlencoded;charset=UTF-8",
#                 type: "post",
#                 dataType: "json",
#                 data: "{}",
#                 success: function (rstData, status) {
#                     // console.log(status, rstData);
#                     if (status !== "success") {
#                         alert('서버와 통신중 오류가 발생하였습니다.');
#                     }
#                     const topMenuId = $("#pageSidebarMenu");
#
#                     let subMenuId = "";
#                     let thirdMenuId = "";
#
#                     /**
#                      * @type Array<{ menuLvl: number, bscPageUrlAddr: string, subMenuCnt: number, menuId: string, popupYn: string, menuNm: string }>
#                      */
#                     const menuList = rstData.rtnList;
#                     // console.log("fnLeftMenuCreate", menuList);
#                     menuList.forEach((menu, i) => {
#                         let defaultUrl = "";
#                         let subMenuContent = "";
#
#                         let activeYn = "";
#                         let selectYn = "";
#
#                         if (menu.menuLvl === 1) {
#                             if (menu.bscPageUrlAddr !== "") {
#                                 defaultUrl = "/cmq" + menu.bscPageUrlAddr;
#                             } else {
#                                 defaultUrl = "javascript:;";
#                             }
#
#                             const arrowMark = menu.subMenuCnt > 0 ? "<span class='arrow'></span>" : "";
#
#                             if (menu.menuId === menuInfo.activeMenuId || menu.menuId === menuInfo.upperMenuId || menu.menuId === menuInfo.menuRootId) {
#                                 activeYn = "active";
#                             } else {
#                                 activeYn = "";
#                             }
#
#                             let mainMenuContent = "";
#                             if (menu.popupYn === "Y") {
#                                 mainMenuContent = $("<li class='nav-item " + activeYn + "' id='mainMenu" + i + "' style='word-break:keep-all;word-wrap:break-word;'><a href='javascript:open_menuUrl(\"/cmq" + menu.bscPageUrlAddr + "\");' class='nav-link nav-toggle'><span class='title'>" + menu.menuNm + "</span>" + arrowMark + " <img src=\"/cmq/com/img/common/icon/icon_popup_url.png\" alt='icon' width=10 height=10></a></li>");
#                             } else {
#                                 mainMenuContent = $("<li class='nav-item " + activeYn + "' id='mainMenu" + i + "' style='word-break:keep-all;word-wrap:break-word;'><a href='" + defaultUrl + "' class='nav-link nav-toggle'><span class='title'>" + menu.menuNm + "</span>" + arrowMark + "</a></li>");
#                             }
#
#                             $(topMenuId).append(mainMenuContent);
#                             let mainMenuId = $("#mainMenu" + i);
#
#                             if (menu.subMenuCnt > 0) {
#                                 const subMenuArea = $("<ul class='sub-menu' id='subMenu" + i + "'></ul>");
#                                 $(mainMenuId).append(subMenuArea);
#                                 subMenuId = $("#subMenu" + i);
#                             }
#
#                         } else if (menu.menuLvl === 2) {
#
#                             if (menu.bscPageUrlAddr !== "") {
#                                 defaultUrl = "/cmq" + menu.bscPageUrlAddr;
#                             } else {
#                                 defaultUrl = "javascript:;";
#                             }
#
#                             let arrowMark = menu.subMenuCnt > 0 ? "<span class='arrow'></span>" : "";
#                             if (menu.menuId === menuInfo.activeMenuId || menu.menuId === menuInfo.upperMenuId || menu.menuId === menuInfo.upperUpperMenuId) {
#                                 activeYn = "active";
#                                 selectYn = "selected";
#                                 if (menu.subMenuCnt > 0) {
#                                     arrowMark = "<span class='arrow open'></span>";
#                                 }
#                             } else {
#                                 activeYn = "";
#                                 selectYn = "";
#                             }
#
#                             if (menu.popupYn === "Y") {
#                                 subMenuContent = $("<li class='nav-item " + activeYn + "' id='level2Menu" + i + "'><a href='javascript:open_menuUrl(\"/cmq" + menu.bscPageUrlAddr + "\");' class='nav-link nav-toggle'><span class='title'>" + menu.menuNm + " <img src=\"/cmq/com/img/common/icon/icon_popup_url.png\" alt='icon' width=10 height=10></span><span class='" + selectYn + "'></span></a></li>");
#                             } else {
#                                 subMenuContent = $("<li class='nav-item " + activeYn + "' id='level2Menu" + i + "'><a href='" + defaultUrl + "' class='nav-link nav-toggle'><span class='title'>" + menu.menuNm + "</span><span class='" + selectYn + "'></span>" + arrowMark + "</a></li>");
#                             }
#
#                             $(subMenuId).append(subMenuContent);
#                             const level2MenuId = $("#level2Menu" + i);
#
#                             if (menu.subMenuCnt > 0) {
#                                 //3레벨 서브메뉴아이디
#                                 //thirdMenuArea = $("<ul class='sub-menu' id='thirdMenu"+i+"'></ul>");
#                                 const thirdMenuArea = $("<ul class='sub-menu sub-menu-depth3' id='thirdMenu" + i + "' style='padding-top: 0px; padding-bottom: 0px;'></ul>");
#                                 $(level2MenuId).append(thirdMenuArea);
#                                 thirdMenuId = $("#thirdMenu" + i);
#                             }
#
#                         } else if (menu.menuLvl === 3) {
#
#                             if (menu.menuId === menuInfo.activeMenuId || menu.menuId === menuInfo.upperUpperMenuId) {
#                                 activeYn = "active";
#                                 selectYn = "selected";
#                             } else {
#                                 activeYn = "";
#                                 selectYn = "";
#                             }
#
#                             if (menu.popupYn === "Y") {
#                                 subMenuContent = $("<li class='nav-item " + activeYn + "'><a href='javascript:open_menuUrl(\"/cmq" + menu.bscPageUrlAddr + "\");' class='nav-link nav-toggle'><span class='title'>" + menu.menuNm + " <img src=\"/cmq/com/img/common/icon/icon_popup_url.png\" alt='icon' width=10 height=10></span><span class='" + selectYn + "'></span></a></li>");
#                             } else {
#                                 subMenuContent = $("<li class='nav-item " + activeYn + "'><a href='/cmq" + menu.bscPageUrlAddr + "' class='nav-link nav-toggle'><span class='title'>" + menu.menuNm + "</span><span class='" + selectYn + "'></span></a></li>");
#                             }
#
#                             $(thirdMenuId).append(subMenuContent);
#                         }
#                     })
#
#
#                     //contentWrapper 최소높이값 조정
#                     //console.log("page-sidebar-wrapper height="+$(".page-sidebar-wrapper").height());
#                     //console.log("contentWrapper height="+$(".contentWrapper").height());
#                     let sidebar_height = 0;
#                     let contentWrapper_height = 0;
#
#                     if ($(".page-sidebar-wrapper").length > 0) sidebar_height = parseInt($(".page-sidebar-wrapper").height());
#
#                     if ($(".contentWrapper").length > 0) {
#                         contentWrapper_height = parseInt($(".contentWrapper").height());
#                         if (sidebar_height > contentWrapper_height) {
#                             $(".contentWrapper").css('min-height', sidebar_height + 'px');
#                         }
#                     }
#                 }
#             });
#         }
#
#         // TOP 메뉴 타이틀 출력
#         function fnTopMenuTitleCreate() {
#             $.ajax({
#                 url: "/cmq/com/selectTopMenuTitleAjax.do",
#                 contentType: "application/x-www-form-urlencoded;charset=UTF-8",
#                 type: "post",
#                 dataType: "json",
#                 data: "{}",
#                 success: function (rstData, status) {
#                     if (status !== "success") {
#                         alert('서버와 통신중 오류가 발생하였습니다.');
#                     }
#
#                     /**
#                      * @type Array<{ sysCd:string, topMenuUrl: string, systemNm: string }>
#                      */
#                     const menuList = rstData.rtnList;
#                     // console.log("fnTopMenuTitleCreate", menuList);
#
#                     menuList.forEach(menu => {
#                         const topMenuUrl = menu.topMenuUrl ? "/cmq" + menu.topMenuUrl : "#";
#
#                         let className = "";
#                         if (menu.sysCd === menuInfo.systemCd) {
#                             className = menuInfo.sysPageUriActive;
#                         }
#
#                         const topMenuTitle = $("<a href='" + topMenuUrl + "' class='" + className + "'>" + menu.systemNm + "</a>");
#                         $("#title_" + menu.sysCd).append(topMenuTitle);
#                     })
#                 }
#             });
#         }
#
#         function fnMsgUnreadCount(){
#             $.ajax({
#                 url         : "/cmq/com/selectMsgUnreadCountAjax.do",
#                 contentType : "application/x-www-form-urlencoded;charset=UTF-8",
#                 type        : "post",
#                 dataType    : "json",
#                 data		   : "{}",
#                 success     : function(rstData, status){
#                     if(status == "success"){
#                         if(rstData.msgUnreadCount!="0"){
#                             $('#msgCount').html("쪽지도착("+rstData.msgUnreadCount+"건)");
#                             $('#msgCount').addClass("textR");
#                             $('#msgCount').addClass("font-bold");
#                         }
#                     }else{
#                         alert('서버와 통신중 오류가 발생하였습니다.');
#                     }
#                 }
#             });
#         }
#
#         // TOP 메뉴 출력(권한 적용)
#         function fnTopMenuCreate() {
#             $.ajax({
#                 url: "/cmq/com/selectTopMenuAjax.do",
#                 contentType: "application/x-www-form-urlencoded;charset=UTF-8",
#                 type: "post",
#                 dataType: "json",
#                 data: "{}",
#                 success: function (rstData, status) {
#                     if (status !== "success") {
#                         alert('서버와 통신중 오류가 발생하였습니다.');
#                     }
#
#                     /**
#                      * @type Array<{ sysCd:string, topMenuUrl: string, systemNm: string, popupYn: string, menuUrl: string, menuNm: string }>
#                      */
#                     const menuList = rstData.rtnList;
#                     // console.log("fnTopMenuCreate", menuList);
#
#                     menuList.forEach(menu => {
#                         const topMenuId = $("#" + menu.sysCd);
#                         let topMenuContent = "";
#                         if (menu.menuUrl) {
#                             if (menu.popupYn === "Y") {
#                                 topMenuContent += "<li style='list-style-type:none;word-break:keep-all;word-wrap:break-word;'>";
#                                 topMenuContent += "  <a href='javascript:open_menuUrl(\"/cmq" + menu.menuUrl + "\");'>";
#                                 topMenuContent += menu.menuNm;
#                                 topMenuContent += "    <img src=\"/cmq/com/img/common/icon/icon_popup_url.png\" alt='icon' width=10 height=10>";
#                                 topMenuContent += "  </a>";
#                                 topMenuContent += "</li>";
#                             } else {
#                                 topMenuContent += "<li style='list-style-type:none;word-break:keep-all;word-wrap:break-word;'>";
#                                 topMenuContent += "  <a href='/cmq" + menu.menuUrl + "'>"
#                                 topMenuContent += menu.menuNm;
#                                 topMenuContent += "  </a>";
#                                 topMenuContent += "</li>"
#                             }
#                         }
#
#                         $(topMenuId).append(topMenuContent);
#                     })
#                 }
#             });
#         }
#
#         function go_login(flag) {
#             document.loginForm.target = '_self';
#             document.loginForm.action = "/cmq/com/loginProc.do";
#             document.loginForm.submit();
#         }
#
#         function go_logout(flag) {
#             document.logoutForm.target = '_self';
#             document.logoutForm.action = "/cmq/com/logoutProc.do";
#             document.logoutForm.submit();
#         }
#
#         function go_myPage() {
#             //var url ="/cmq/qmy/tempList.do";
#             //var url ="/cmq/qim/testInsptr/testInsptrAList.do";
#
#             var url = ""
#             document.location.href = "/cmq" + url;
#         }
#
#         function open_menuUrl(url) {
#             window.open(url, "_blank", "");
#         }
#
#         function go_menuUrl(url,type) {
#             if(url == ""){
#                 return alert("접근권한이 필요한 메뉴입니다. 로그인 후 사용해 주시기 바랍니다.");
#             }
#             if(type == 'CMQ'){
#                 url = _contextPath + url;
#             }
#             window.open(url,"_self","");
#         }
#
#         $(function () {
#             $(".detail-search-btn").detailSch();	// 통합검색 상세옵션보기
#             $(".total-search-bar").selectSch();		// 통합검색 흰트 상세옵션보기
#         });
#
#         // 상세 검색 - Show / Hide
#         $.fn.detailSch = function () {
#             return this.each(function () {
#                 var $obj = $(this),
#                     $tgt = $(".detail-option-wrapper")
#                 $tgtPage = $(".top-total-search")
#                 ;
#
#                 $obj.on("click", function () {
#                     if (!$obj.hasClass("on")) {
#                         $obj.addClass("on");
#                         $tgt.addClass("on");
#                         $tgtPage.addClass("detail-option-active");
#                     } else {
#                         $obj.removeClass("on");
#                         $tgt.removeClass("on");
#                         $tgtPage.removeClass("detail-option-active");
#                     }
#                 });
#
#                 $tgt.find(".btn-close").on("click", function () {
#                     $obj.removeClass("on");
#                     $tgt.removeClass("on");
#                     $tgtPage.removeClass("detail-option-active");
#                 });
#             });
#         };
#
#         // 통합검색 흰트 - Show / Hide
#         $.fn.selectSch = function () {
#             return this.each(function () {
#                 var $obj = $(this),
#                     $tgt = $(".search-select")
#                 ;
#
#                 $obj.on("click", function () {
#                     if (!$tgt.hasClass("on")) {
#                         $tgt.addClass("on");
#                     } else {
#                         $tgt.removeClass("on");
#                     }
#                 });
#
#                 $obj.on("focusout", function () {
#                     if ($tgt.hasClass("on")) {
#                         $tgt.removeClass("on");
#                     }
#                 });
#             });
#         };
#
#         //통합검색
#         function go_sch_search() {
#
#             setCookie("diquest", $("#searchTerm").val()); //최근검색어 추가
#
#             var chkArray = new Array(); // 배열 선언
#
#             if ($('#chk_all').is(':checked')) {
#                 $("#searchRange").val('all');
#             } else {
#                 $('input:checkbox[]:checked').each(function () { // 체크된 체크박스의 value 값을 가지고 온다.
#                     chkArray.push(this.value);
#                 });
#                 $('#searchRange').val(chkArray);
#             }
#
#             var order = $('input[name=radioInline]:checked').val();
#
#             $("#order").val(order);
#             $("#searchType").val('');
#             $("#check").val('2');
#             $('#diquestForm').attr('action', '/search/schTotalList.do');
#             $('#diquestForm').attr('target', '_blank');
#             $('#diquestForm').submit();
#
#         }
#
#         //최근검색어,인기검색어 자동완성 누르고 검색
#         function keywordSearch(searchTerm) {
#             alert('aasd');
#             setCookie("diquest", $("#searchTerm").val()); //최근검색어 추가
#             $("#searchTerm").val(searchTerm);
#
#             go_sch_search();
#         }
#
#         //자동완성
#         var index = 0;
#
#         function autoCompletes(event) {
#             var originTag = $("#searchTerm").val();
#             var code = event.keyCode; //키보드 이벤트 키 값
#
#             var checkCount = 0;
#
#
#             if (code != 40 && code != 38 && code != 13) {
#                 //alert($("#searchTerm").val());
#                 $.ajax({
#                     type: "GET",
#                     url: "/search/autoCompleteAjax.do",
#                     data: {"keyword": $("#searchTerm").val()},
#                     async: false,
#                     dataType: "json",
#                     error: function () {
#
#                     },
#                     success: function (rstData, status) {
#                         var text = "";
#                         text += "<ul>";
#
#                         var arrLength = rstData.rtnList.length;
#
#                         if (arrLength > 0) {
#
#                             var keyword = "";
#                             var count = "";
#
#
#                             for (var i = 0; i < arrLength; i++) {
#                                 var rowObj = rstData.rtnList[i];
#
#                                 keyword = rowObj.keyword;
#                                 count = rowObj.count;
#
#
#                                 checkCount = arrLength + 1;
#
#                                 text += "<li><a href='javascript:void(0);' onclick='keywordSearch(\"" + keyword + "\")';>" + keyword + "</a></li>"
#
#                                 //text += "<li><a href='javascript:void(0);' onclick='keywordSearch(";
#                                 //text +=  '"'+keyword+'"';
#                                 //text += ");";
#
#                             }
#
#                         } else {
#                             text = "<li>검색 결과가 없습니다.</li>";
#                         }
#                         text += "<ul>";
#
#                         $("#search-select").html(text);
#                     }
#
#                 });
#             }
#
#
#             var len = $("#search-select > ul > li").length;//검색된 리스트 수
#
#
#             if (len > 0) {  //검색결과가 하나라도 있는 경우
#                 var start = index;
#                 if (code == 40) {    //아래방향키 눌렀을 때
#                     index++;
#                     if (index > len) {  //마지막 인덱스 까지 간 경우
#
#                         $("#search-select > ul > li:nth-child(" + (index - 1) + ")").css('background-color', '');
#
#                         index = 0;
#                         $("input[name=searchTerm]").val(originTag);  //검색창에 처음 입력한 검색값을 넣는다.
#                         return;
#                     } else {
#                         if (index >= 0) { //정상적인 경우
#                             var tagName = $.trim($("#search-select > ul > li:nth-child(" + index + ") a").text());
#                             $("input[name=searchTerm]").val(tagName);
#                             $("#search-select > ul > li:nth-child(" + index + ")").css('background-color', '#D5D5D5');
#                             $("#search-select > ul > li:nth-child(" + (index - 1) + ")").css('background-color', '');
#
#
#                         }
#                         //index++;
#
#                     }
#                 } else if (code == 38) {
#                     index--;
#                     if (index == 0) {
#                         $("input[name=searchTerm]").val(originTag);
#                         $("#search-select > ul > li:nth-child(" + (index + 1) + ")").css('background-color', '');
#                     } else {
#                         if (index < 0) {
#                             index = len + 1;
#                         } else {
#                             var tagName = $.trim($("#search-select > ul > li:nth-child(" + index + ") a").text());
#                             $("input[name=searchTerm]").val(tagName);
#                             $("#search-select > ul > li:nth-child(" + index + ")").css('background-color', '#D5D5D5');
#                             $("#search-select > ul > li:nth-child(" + (index + 1) + ")").css('background-color', '');
#                         }
#                     }
#
#                 }
#             }
#
#         }
#
#
#     </script>
# <!-- LDB, 210621 추가, 세션 타임아웃에 따른 자동 로그아웃 -->
# <script language="javascript">
#         $(function () {
#             var toMd = ""
#             toMd += "	<div class='modal fade' id='timeOutModal' tabindex='-1' data-backdrop='static' data-keyboard='false' style='display: none;'>"
#             toMd += "	<div class='modal-dialog' style='width:520px;'>"
#             toMd += "		<div class='modal-content'>"
#             toMd += "			<div class='modal-header'>"
#             toMd += "				<h4 class='modal-title'>로그아웃 알림</h4>"
#             toMd += "			</div>"
#             toMd += "			<div class='modal-body'>"
#             toMd += "				<div class='table-top-control'>"
#             toMd += "					<!-- 알림 시작 -->"
#             toMd += "					<div class='notice-view'>"
#             toMd += "						<img class='notice-view-ico' src='/cmq/com/img/common/icon/ico_view_notice.png' alt='notice'>"
#             toMd += "						<span>장시간 사용하지 않아 </span><span id='timeoutView' class='textR'></span><span>초 후 자동 로그아웃됩니다. </span>"
#             toMd += "					</div>"
#             toMd += "				</div>"
#             toMd += "				<div class='modal-footer'>"
#             toMd += "					<button type='button' class='btn btn-danger' data-dismiss='modal' onclick='timeOutModal_choice(`r`);'>연장</button>"
#             toMd += "					<button type='button' class='btn dark btn-outline' data-dismiss='modal' onclick='timeOutModal_choice(`c`);'>로그아웃</button>"
#             toMd += "				</div>"
#             toMd += "			</div>"
#             toMd += "		</div>"
#             toMd += "	</div>"
#             toMd += "</div>"
#
#             $("body").append(toMd);
#
#
#         });
#
#         function timeOutModal_choice(type) {
#             if (type == 'r') {
#                 window.location.reload();
#             } else if (type == 'c') {
#                 go_logout();
#             }
#         }
#
#         function go_timeOutModal() {
#             $("#timeOutModal").modal();
#         }
#
#         function autoLogout() {
#             $.ajax({
#                 type: "post",
#                 url: "/com/autoLogoutAjax.do",
#                 data: "",
#                 success: function (data) {
#                     if (data.isOk == "Y") {
#                         alert("장시간 사용하지 않아 접속이 차단되었습니다. 재로그인 후 사용하시기 바랍니다.");
#                         $("#timeOutModal").modal("hide");
#                         window.location.href = _contextPath + '/index.do';
#                     } else {
#                         go_logout();
#                     }
#                 },
#                 error: function (error) {
#                     go_logout();
#                 }
#             });
#         }
#
#     </script>
# <script language="javascript">
# 			var user_id = "";
# 			$(document).ready(function () {
# 				$('#page_title').html(menuInfo.menuNm);
# 				$('#page_desc').html(menuInfo.menuDesc);
#
# 				fnTopMenuTitleCreate();
# 				fnTopMenuCreate();
# 				fnLeftMenuCreate(menuInfo.systemCd);
#
# 				if (!user_id) {
# 					fnMsgUnreadCount();
# 				}
#
# 			});
# 		</script>
# </link></link></meta></head>
# <!-- head 끝 -->
# <body class="page-content-white page-front page-renewal top-total-search"> <!-- 가로 꽉찬화면은 class="page-full-screen"를 추가합니다. -->
# <script language="javascript">
#
#
#
#
#
#
#
# 	const handleMoveSignUpPage = () => {
# 		alert('회원가입 및 회원정보수정은\n건설공사 안전관리 종합정보망(CSI)에서 수행할 수 있습니다.');
# 		window.location.href = "https://www.csi.go.kr/por/realNameCerti.do";
# 	}
# </script>
# <div class="page-wrapper">
# <!-- skip To Content 시작 -->
# <div id="skipToContent">
# <!--250924 웹 접근성 점검으로 인해 주석처리  <a href="#content">본문 바로가기</a> -->
# <!-- <a href="#gnb">주메뉴 바로가기</a> -->
# </div>
# <script>
# 				$('#skipToContent a').on('focus', function(){
# 					$(this).stop().animate({"top":0, "opacity":1});
# 				});
# 				$('#skipToContent a').on('click', function(){
# 					$(this).stop().animate({"top":"-30px", "opacity":0});
# 				});
# 				$('#skipToContent a').on('focusout', function(){
# 					$(this).stop().animate({"top":"-30px", "opacity":0});
# 				});
# 			</script>
# <!-- skip To Content 끝 -->
# <!-- 글로벌 시작 -->
# <div class="page-header navbar navbar-fixed-top">
# <div class="page-header-inner">
# <div class="page-logo">
# <a href="/cmq/index.do">
# <span class="logo-default"><img alt="logo" src="/cmq/com/img/main_renewal/header/logo_quality.png"/></span>
# </a>
# </div>
# <!-- 홈으로 가기 시작 -->
# <div class="quality-btn-group">
# <a class="quality-btn ico-btn-l ico-arrow" href="https://www.csi.go.kr/index.do">건설안전 바로가기</a>
# </div>
# <!-- 홈으로 가기 끝 -->
# <!-- 로그아웃 했을때 시작 -->
# <div class="top-menu">
# <form action="#" id="loginForm" method="post" name="loginForm">
# <input name="bbsId" type="hidden" value=""/>
# <input name="bbsNo" type="hidden" value=""/>
# <input id="case_no" name="caseNo" type="hidden" value=""/>
# <input id="nextUrl" name="nextUrl" type="hidden" value="/qtr/qltRqst/rqstRcvList.do"/>
# <input id="reprt_seq" name="reprtSeq" type="hidden" value=""/> <!--2025-06-13 이영호 최종 복원 필요-->
# <ul class="nav navbar-nav pull-right">
# <li class="dropdown dropdown-extended dropdown-user">
# <div class="form-inline">
# <div class="form-group">
# <label class="control-label visible-ie8 visible-ie9" for="user_id">아이디</label>
# <div class="input-icon">
# <i class="fa fa-user"></i>
# <input autocomplete="off" class="form-control" id="userId" maxlength="20" name="userId" placeholder="아이디" style="width: 120px;" tabindex="1" type="text" value=""/>
# </div>
# </div>
# <div class="form-group">
# <label class="control-label visible-ie8 visible-ie9" for="pswd">비밀번호</label>
# <div class="input-icon">
# <i class="fa fa-lock"></i>
# <input autocomplete="off" class="form-control" id="pswd" name="pswd" onkeydown="if (event.keyCode == 13) go_login('N')" placeholder="비밀번호" style="width: 120px;" tabindex="2" type="password" value=""/>
# </div>
# </div>
# </div>
# </li>
# <li class="dropdown dropdown-extended dropdown-inbox">
# <a class="login-btn" href="javascript:go_login('N')">로그인</a>
# </li>
# <li class="dropdown dropdown-extended dropdown-inbox">
# <a class="user-btn" onclick="handleMoveSignUpPage()">회원가입</a>
# </li>
# <li class="dropdown dropdown-extended dropdown-inbox">
# <a class="idpw-btn" href="https://www.csi.go.kr/por/findUserCertiPop.do" onclick="window.open(this.href,'_blank','width=400,height=400,menubar=no,toolbar=no,scrollbars=yes,resizable=yes'); return false;">아이디/비밀번호 찾기</a>
# </li>
# <li class="dropdown dropdown-extended dropdown-inbox">
# <a class="dropdown-toggle top-btn btn-sitemap" href="/cmq/qus/sys/siteMap.do">사이트맵</a>
# </li>
# </ul>
# </form>
# </div>
# <!-- 로그아웃 했을때 끝 -->
# <!-- 메뉴 시작 -->
# <!-- 전체메뉴 끝 -->
# <div class="nav-header-bg"></div>
# <div class="navbar-collapse-wrapper">
# <div class="navbar-collapse collapse" id="navbar">
# <ul class="nav navbar-nav">
# </ul>
# </div>
# </div>
# <!-- 메뉴 끝 -->
# </div>
# </div>
# <!-- 글로벌 끝 -->
# <!-- 헤더 & 컨텐츠 분할 시작 -->
# <div class="clearfix"> </div>
# <!-- 헤더 & 컨텐츠 분할 끝 -->
# <!-- container 시작 -->
# <div class="page-container">
# <!-- 페이지 레이아웃 시작 -->
# <div class="page-content-wrapper">
# <div class="page-content" id="contents">
# <!-- 서브 비주얼 시작 -->
# <div class="page-sub-visual sub-visual-type-01">
# <div class="page-sub-visual-inner"></div>
# </div>
# <!-- 서브 비주얼 끝 -->
# <!-- 페이지바 시작 -->
# <div class="page-bar hor-menu">
# <div class="page-bar-inner">
# <!-- 카테고리 시작 -->
# <ul class="page-breadcrumb">
# </ul>
# <!-- 카테고리 끝 -->
# <!-- 컨텐츠 옵션 시작 -->
# <ul class="page-options">
# <li class="page-options-print tooltips" data-container="body" data-original-title="프린트" data-placement="bottom" style="line-height: 0px;"><a id="print-preview"></a></li>
# </ul>
# <!-- 컨텐츠 옵션 끝 -->
# </div>
# </div>
# <!-- 페이지바 끝 -->
# <form action="" id="menu" method="post" name="menu">
# <input name="menu_id" type="hidden" value=""/>
# <input name="nextUrl" type="hidden" value=""/>
# <input name="p_dign_gbn" type="hidden" value=""/>
# <!-- 왼쪽메뉴 시작 -->
# <div class="page-sidebar-wrapper">
# <div class="page-sidebar navbar-collapse collapse">
# <ul class="page-sidebar-menu page-header-fixed" data-auto-scroll="true" data-keep-expanded="false" data-slide-speed="200" id="pageSidebarMenu">
# <li class="heading">
# <h2 class="heading-title"> </h2>
# </li>
# </ul>
# </div>
# </div>
# <!-- 왼쪽메뉴 끝 -->
# </form>
# <!-- 통합메세지 발송 -->
# <form id="form_sendMsgPop" method="post" name="form_sendMsgPop">
# <input name="inst_nm" type="hidden"/>
# <input name="inst_chrgr_nm" type="hidden"/>
# <input name="hp_no" type="hidden"/>
# <input name="inst_chrgr_id" type="hidden"/>
# </form>
# <!-- 그룹웨어 팝업창을 위한 form -->
# <form id="form_gwPop" method="post" name="form_gwPop">
# <input name="key" type="hidden"/>
# <input name="code1" type="hidden"/>
# </form>
# <!-- 컨텐츠 시작 -->
# <div class="contentWrapper" id="divRight">
# <script type="text/javascript">
#      alert('로그인이 필요한 메뉴입니다.\n로그인을 진행해 주시기 바랍니다.');
#      location.href='/cmq/index.do';
# </script>
# </div>
# <!-- 컨텐츠 끝 -->
# </div>
# </div>
# <!-- 페이지 레이아웃 끝 -->
# </div>
# <!-- container 끝 -->
# <!-- footer 시작 -->
# <div class="page-footer">
# <div class="page-footer-inner">
# <div class="page-footer-logo">
# <img alt="국토교통부" src="/cmq/com/img/main_renewal/footer/logo_footer.png">
# </img></div>
# <div class="page-footer-container">
# </div>
# <div class="page-footer-link">
# <ul class="page-footer-info">
# <li><a href="https://www.csi.go.kr/por/serviceinfo.do?bbt_no=335">이용약관</a></li>
# <li><a href="https://www.csi.go.kr/por/privacyPolicy.do" style="color:red; font-weight: bold;">개인정보 처리방침</a></li>
# <li><a href="https://www.kalis.or.kr/wpge/m_280/guide/guide04.do" target="_blank">고정형 영상정보처리기기<br/>운영관리방침(국토안전관리원)</a></li>
# <li><a href="https://www.csi.go.kr/por/serviceinfo.do?bbt_no=337">공공데이터 이용정책</a></li>
# <li><a href="https://www.csi.go.kr/por/serviceinfo.do?bbt_no=338">이메일주소 무단 수집 거부</a></li>
# <li><a href="http://stat.molit.go.kr/portal/quality/qualityCenterWrite.do?system_id=S0066">품질오류신고</a></li>
# </ul>
# <div class="page-footer-institution">
# <div class="page-footer-select-set">
# <div class="select-container">
# <label for="relationSite" style="display: none;">관련사이트 링크 바로가기</label>
# <select class="bs-select form-control" id="relationSite" onchange="if(this.value != '') window.open(this.value);">
# <option value="">::: 관련사이트 링크 바로가기 :::</option>
# </select>
# </div>
# <button class="btn dark" onclick="moveUrl()" type="button">이동</button>
# </div>
# </div>
# </div>
# </div>
# <div class="scroll-to-top">
# <i class="icon-arrow-up"></i>
# </div>
# </div>
# <!-- footer 끝 -->
# </div>
# <div id="divCommModal"></div>
# </body>
# </html>
